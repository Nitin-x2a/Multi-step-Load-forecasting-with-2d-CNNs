# %%
import backend
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('megawatts.csv')

# %%
fest = pd.read_csv('festival.csv')

# %%
window = [-1, -2, -3, 0, 1, 2, 3]
d_number = 12
w_number = 12
new_df = backend.mach3(df, fest, window, d_number, w_number)
new_df
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                      load_(t-93)  load_(t-94)  ...       t-w84     load
# datetime                                       ...
# 2016-12-05 04:30:00      346.864      350.032  ...  318.874172  338.420
# 2016-12-05 04:45:00      350.568      346.864  ...  321.274168  336.284
# 2016-12-05 05:00:00      354.116      350.568  ...  321.192712  338.324
# 2016-12-05 05:15:00      369.824      354.116  ...  328.098896  339.488
# 2016-12-05 05:30:00      356.284      369.824  ...  337.274172  340.072
# ...                          ...          ...  ...         ...      ...
# 2019-12-30 22:45:00      526.000      532.000  ...  483.000000  546.000
# 2019-12-30 23:00:00      522.000      526.000  ...  485.000000  543.000
# 2019-12-30 23:15:00      513.000      522.000  ...  474.000000  532.000
# 2019-12-30 23:30:00      507.000      513.000  ...  474.000000  524.000
# 2019-12-30 23:45:00      494.000      507.000  ...  465.000000  513.000
#
# [107400 rows x 169 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(new_df)

# %%
scaled_data.shape
# Out:
# (107400, 169)

# %%
train_data = scaled_data[:-30*96]
test_data = scaled_data[-30*96:]

# %%
X_train = train_data[:, :-1]
Y_train = train_data[:, -1]

X_test = test_data[:, :-1]
Y_test = test_data[:, -1]

# %%
X_train.shape
# Out:
# (104520, 168)

# %%
X_train = X_train.reshape(X_train.shape[0], 6, 7, 4)
X_test = X_test.reshape(X_test.shape[0], 6, 7, 4)

# %%
from sklearn.model_selection import train_test_split

X1, X2, Y1, Y2 = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense, concatenate, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
  input = Input(shape=(X_train.shape[1], X_train.shape[2], X_train.shape[3]))

  conv1a = Conv2D(filters = 4, kernel_size = (1, 1), padding='same', activation='relu')(input)
  conv1b = Conv2D(filters = 4, kernel_size = (1, 3), padding='same', activation='relu')(input)
  conv1c = Conv2D(filters = 4, kernel_size = (1, 5), padding='same', activation='relu')(input)
  conv1d = Conv2D(filters = 2, kernel_size = (3, 3), padding='same', activation='relu')(input)
  conv1e = Conv2D(filters = 1, kernel_size = (5, 5), padding='same', activation='relu')(input)
  conv1f = Conv2D(filters = 1, kernel_size = (3, 5), padding='same', activation='relu')(input)
  conv1g = Conv2D(filters = 1, kernel_size = (5, 3), padding='same', activation='relu')(input)
  conv1h = Conv2D(filters = 4, kernel_size = (5, 1), padding='same', activation='relu')(input)
  conv1i = Conv2D(filters = 4, kernel_size = (3, 1), padding='same', activation='relu')(input)

  merged = concatenate([conv1a, conv1b, conv1c, conv1d, conv1e, conv1f, conv1g, conv1h, conv1i], axis=-1)
  norm1 = BatchNormalization()(merged)

  conv2 = Conv2D(filters = 8, kernel_size = (3, 3), activation='relu')(norm1)
  norm2 = BatchNormalization()(conv2)

  conv3 = Conv2D(filters = 8, kernel_size = (3, 3), activation='relu')(norm2)
  norm3 = BatchNormalization()(conv3)

  conv4 = Conv2D(filters = 16, kernel_size = (2, 2), activation='relu')(norm3)
  norm4 = BatchNormalization()(conv4)

  conv5 = Conv2D(filters = 8, kernel_size = (1, 2), activation='relu')(norm4)
  norm5 = BatchNormalization()(conv5)

  flatten = Flatten()(norm5)

  output = Dense(1, activation='relu')(flatten)

  model = Model(input, output)

  model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6, 7, 4)]    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 6, 7, 4)      20          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 6, 7, 4)      52          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 6, 7, 4)      84          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 6, 7, 2)      74          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 6, 7, 1)      101         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 6, 7, 1)      61          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 6, 7, 1)      61          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 6, 7, 4)      84          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 6, 7, 4)      52          input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6, 7, 25)     0           conv2d[0][0]
#                                                                  conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6, 7, 25)     100         concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 5, 8)      1808        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4, 5, 8)      32          conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 2, 3, 8)      584         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 2, 3, 8)      32          conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 2, 16)     528         batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1, 2, 16)     64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 8)      264         batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1, 1, 8)      32          conv2d_12[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8)            0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            9           flatten[0][0]
# ==================================================================================================
# Total params: 4,042
# Trainable params: 3,912
# Non-trainable params: 130
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
save_at = "model.hdf5"
save_best = ModelCheckpoint(save_at, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='min')

# %%
model.compile(optimizer=Adam(0.001), loss='mean_squared_error')

history = model.fit( X1, Y1, 
                    epochs = 10, batch_size = 32, 
                    callbacks=[save_best], verbose=1, 
                    validation_data = (X2, Y2))
# Out:
# Epoch 1/10
# 2777/2777 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 00001: val_loss improved from inf to 0.00252, saving model to model.hdf5
# 2777/2777 [==============================] - 19s 7ms/step - loss: 0.0162 - val_loss: 0.0025
# Epoch 2/10
# 2777/2777 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00002: val_loss did not improve from 0.00252
# 2777/2777 [==============================] - 17s 6ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 3/10
# 2770/2777 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 00003: val_loss did not improve from 0.00252
# 2777/2777 [==============================] - 17s 6ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 4/10
# 2770/2777 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 00004: val_loss did not improve from 0.00252
# 2777/2777 [==============================] - 17s 6ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 5/10
# 2770/2777 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 00005: val_loss did not improve from 0.00252
# 2777/2777 [==============================] - 17s 6ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 6/10
# 2771/2777 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 00006: val_loss did not improve from 0.00252
# 2777/2777 [==============================] - 17s 6ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 7/10
# 2770/2777 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 00007: val_loss did not improve from 0.00252
# 2777/2777 [==============================] - 18s 6ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 8/10
# 2775/2777 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 00008: val_loss improved from 0.00252 to 0.00205, saving model to model.hdf5
# 2777/2777 [==============================] - 17s 6ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 9/10
# 2772/2777 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 00009: val_loss did not improve from 0.00205
# 2777/2777 [==============================] - 18s 6ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 10/10
# 2772/2777 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 00010: val_loss did not improve from 0.00205
# 2777/2777 [==============================] - 17s 6ms/step - loss: 0.0024 - val_loss: 0.0035

# %%
from tensorflow.keras.models import load_model
model = load_model('model.hdf5')

# %%
plt.figure(figsize=(6, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model loss', weight='bold', fontsize=16)
plt.ylabel('loss', weight='bold', fontsize=14)
plt.xlabel('epoch', weight='bold', fontsize=14)
plt.xticks(weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)
plt.legend(['train', 'validation'], loc='upper left', prop={'size': 14})
plt.grid(color = 'y', linewidth='0.5')
plt.show()

# %%
Y_pred = model.predict(X_test)

# %%
target_scaler = MinMaxScaler()

target_scaler.fit(np.array(new_df.iloc[:, 0]).reshape(-1, 1))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
ypred = target_scaler.inverse_transform(Y_pred)

# %%
ytest = target_scaler.inverse_transform(Y_test.reshape(-1, 1))

# %%
index= pd.date_range('12-01-2019 00:00', periods=30*96, freq='15min')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20, 6))
plt.plot(pd.DataFrame(ypred).set_index(index), color='magenta', linewidth=2, label='Predicted')
plt.plot(pd.DataFrame(ytest).set_index(index), color='blue', linewidth=2, label='Actual')

plt.xticks(weight='bold', fontsize=12)

plt.yticks(weight='bold', fontsize=12)

plt.grid(color='orange', linewidth=1)

plt.title('Predictions on Test Set', weight='bold', fontsize=16)

plt.xlabel('Date', weight='bold', fontsize=14)

plt.ylabel('Load (MW) ', weight='bold', fontsize=14)

plt.legend(loc='best', prop={'size': 14, 'weight':'bold'})

plt.savefig('test_out.jpeg')

# %%
from sklearn.metrics import mean_squared_error
error = np.sqrt(mean_squared_error(ypred, ytest))
error
# Out:
# 20.66558850856825

# %%
from sklearn.metrics import r2_score
score = r2_score(ypred, ytest)
score
# Out:
# 0.7847157764631714

# %%
#Mean Absolute Percentage Error

sum(abs((ypred -ytest)/ytest)*100)/len(ytest)
# Out:
# array([3.1827713])
